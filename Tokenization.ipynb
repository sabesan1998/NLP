# %% [markdown]
# Tokenization is a process of splitting text into meaningful segment

# %%
import spacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
nlp = spacy.blank('en')  # creating object with english language 
                        #Create a blank pipeline of a given language class

# %% [markdown]
# By deault nlp object has word tokenizer so if we run a for loop it will actomatically tokenize the text.

# %% [markdown]
# ![Screenshot 2022-12-29 211839.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The tokinzer start with prefix remove and then a expection and then a suffix remover

# %%
doc = nlp('''"Lets's go to N.Y"''')

# %%
for token in doc:
  print(token)
# Out:
# "
# Lets
# 's
# go
# to
# N.Y
# "

# %%
doc = nlp("I need two books")

# %%
token2 = doc[2]
token2
# Out:
# two

# %%
dir(token2)   #functions that can access by this varible
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
#  'is_punct',
# ...

# %%
token2.like_num
# Out:
# True

# %%
with open('/content/students.txt') as f:
  text = f.readlines()

text
# Out:
# ['Dayton high school, 8th grade students information\n',
#  '==================================================\n',
#  '\n',
#  'Name\tbirth day   \temail\n',
#  '-----\t------------\t------\n',
#  'Virat   5 June, 1882    virat@kohli.com\n',
#  'Maria\t12 April, 2001  maria@sharapova.com\n',
#  'Serena  24 June, 1998   serena@williams.com \n',
#  'Joe      1 May, 1997    joe@root.com\n',
#  '\n',
#  '\n',
#  '\n']

# %%
text = ' '.join(text)
text
# Out:
# 'Dayton high school, 8th grade students information\n ==================================================\n \n Name\tbirth day   \temail\n -----\t------------\t------\n Virat   5 June, 1882    virat@kohli.com\n Maria\t12 April, 2001  maria@sharapova.com\n Serena  24 June, 1998   serena@williams.com \n Joe      1 May, 1997    joe@root.com\n \n \n \n'

# %%
doc = nlp(text)

for token in doc:
  if token.like_email:
    print(token)
# Out:
# virat@kohli.com
# maria@sharapova.com
# serena@williams.com
# joe@root.com

# %%
doc = nlp('''gimme dobule cheese extra large pizza''' )
tokens = [token.text for token in doc]
tokens
# Out:
# ['gimme', 'dobule', 'cheese', 'extra', 'large', 'pizza']

# %%
from spacy.symbols import ORTH

nlp.tokenizer.add_special_case("gimme",[{ORTH:"gim"},{ORTH:"me"}])

doc = nlp('''gimme dobule cheese extra large pizza''' )
tokens = [token.text for token in doc]
tokens
# Out:
# ['gim', 'me', 'dobule', 'cheese', 'extra', 'large', 'pizza']

# %%
nlp.add_pipe('sentencizer')

# %%
doc = nlp("sentence 2. Sentence3")

for sentence in doc.sents:
  print(sentence)
# Out:
# sentence 2.
# Sentence3
